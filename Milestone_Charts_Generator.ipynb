# %% [markdown]
# <a href="https://colab.research.google.com/github/nlavee/slt-cs230/blob/main/Milestone_Charts_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()    
objects = ('Baseline', 'Random Synonym Insertion', 'Synonym Replacement', 'Synonym Appended', '3-layers Encoder-Decoder', '4-layers Encoder-Decoder', '6-layers Encoder-Decoder')
y_pos = np.arange(len(objects))
performance = [ 91.8689, 91.5662, 89.9189, 89.7952, 91.7722, 91.6056, 91.1866]

plt.barh(y_pos, performance, align='center', alpha=0.5)

for i, v in enumerate(performance):
    ax.text(v + 1, i, str(v), color='blue', fontweight='bold')

plt.yticks(y_pos, objects)
plt.xlabel('Validation Accuracy')
plt.title('Validation accuracy for various experiments (English Gloss)')

plt.show()

# %%
fig, ax = plt.subplots()    
objects = ('Baseline', 'Random Synonym Insertion', 'Synonym Replacement', 'Synonym Appended', '3-layers Encoder-Decoder', '4-layers Encoder-Decoder', '6-layers Encoder-Decoder')
y_pos = np.arange(len(objects))
performance = [ 536, 554, 543, 544, 620, 704, 872]

plt.barh(y_pos, performance, align='center', alpha=0.5)

for i, v in enumerate(performance):
    ax.text(v + 1, i, str(v), color='blue', fontweight='bold')

plt.yticks(y_pos, objects)
plt.xlabel('Model Size (MB)')
plt.title('Model size for various experiments (English Gloss)')

plt.show()
